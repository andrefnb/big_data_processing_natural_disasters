# %% [markdown]
# # Spark

# %% [markdown]
# ### Download dataset

# %%
# !wget -O natural_disasters_BIG.csv https://www.dropbox.com/s/b74bpkbr89l8k43/natural_disasters_BIG.csv?dl=0

# %% [markdown]
# ### 1. How many disasters occurred in continent C?

# %%
# %%file spark_1.py
import pyspark
from operator import add as sum
sc = pyspark.SparkContext('local[*]')
try :
    # import input CSV file
    lines = sc.textFile('natural_disasters_BIG.csv')
    # separate each line by its columns
    lines = lines.map( lambda line : line.split(","))
    # retrieve only the columns with continents and occurrences
    continents = lines.map( lambda line: (line[5], line[9]))
    # for each continent sum the number of occurrences
    occurrences = continents.reduceByKey(lambda v1,v2: int(v1) + int(v2))
    # print all results
    for oc in occurrences.collect():
        print(f"{oc}\n")
    sc.stop()
except Exception as e:
    print(e)
    sc.stop()
# Out:
# Overwriting spark_1.py

# %%
# !bash -c "time python spark_1.py"
# Out:
# 19/11/12 14:57:23 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# ('Europe', 362135)
#
# ('Oceania', 89256)
#
# ('Africa', 576686)
#
# ('Americas', 626963)
#
# ('Asia', 1191797)
#
#
# real	0m13.909s
# user	0m0.585s
# sys	0m0.201s

# %% [markdown]
# ### 2. In which regions there were disasters of type X?

# %%
# %%file spark_2.py
import pyspark
sc = pyspark.SparkContext('local[*]')
try :
    # import input CSV file
    lines = sc.textFile('natural_disasters_BIG.csv')
    # separate each line by its columns
    lines = lines.map( lambda line : line.split(","))
    # retrieve only the columns with disaster type and regions
    type_region = lines.map( lambda line: (line[3], line[6]))
    # maintain only the distinct regions
    distinct_regions = type_region.distinct()
    # group the regions by disaster type and aggregate them in a list
    region_by_type = distinct_regions.groupByKey().map(lambda x: (x[0], list(x[1])))
    # print all results
    for type_x in region_by_type.collect():
        print(f"{type_x}\n")
    sc.stop()
except Exception as e:
    print(e)
    sc.stop()
# Out:
# Overwriting spark_2.py

# %%
# !bash -c "time python spark_2.py"
# Out:
# 19/11/12 14:58:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# ('Transport accident', ['Western Europe', 'Western Africa', 'Southern Africa', 'Middle Africa', 'South-Eastern Asia', 'Northern America', 'South America', 'Northern Africa', 'Central America', 'Western Asia', 'Polynesia', 'Northern Europe', 'Eastern Europe', 'Southern Europe', 'Southern Asia', 'Eastern Africa', 'Melanesia', 'Eastern Asia', 'Australia and New Zealand', 'Caribbean', 'Russian Federation', 'Central Asia', 'Micronesia'])
#
# ('Drought', ['Eastern Asia', 'South America', 'Australia and New Zealand', 'Northern Africa', 'Western Asia', 'Southern Africa', 'Middle Africa', 'Russian Federation', 'South-Eastern Asia', 'Central Asia', 'Northern America', 'Southern Asia', 'Eastern Africa', 'Western Europe', 'Eastern Europe', 'Melanesia', 'Micronesia', 'Northern Europe', 'Polynesia', 'Caribbean', 'Southern Europe', 'Western Africa', 'Central America'])
#
# ('Insect infestation', ['Western Africa', 'Eastern Africa', 'Southern Asia', 'Middle Africa', 'South America', 'Eastern Europe', 'Central Asia', 'South-Eastern Asia', 'Western Asia', 'Australia and New Zealand', 'Eastern Asia', 'Northern Africa', 'Southern Africa'])
#
# ('Epidemic', ['Southern Africa', 'Eastern Europe', 'Southern Europe', 'Micronesia', 'South America', 'Northern Europe', 'Australia and New Zealand', 'Western Europe', 'Middle Africa', 'Eastern Asia', 'South-Eastern Asia', 'Northern America', 'Eastern Africa', 'Central America', 'Northern Africa', 'Melanesia', 'Central Asia', 'Southern Asia', 'Caribbean', 'Western Africa', 'Russian Federation', 'Western Asia', 'Polynesia'])
#
# ('Wildfire', ['Western Asia', 'Eastern Africa', 'South-Eastern Asia', 'Southern Asia', 'Northern Africa', 'Melanesia', 'Polynesia', 'Western Europe', 'Eastern Asia', 'Central America', 'South America', 'Northern America', 'Caribbean', 'Southern Europe', 'Central Asia', 'Middle Africa', 'Russian Federation', 'Australia and New Zealand', 'Western Africa', 'Southern Africa', 'Eastern Europe', 'Northern Europe'])
#
# ('Animal accident', ['Western Africa'])
#
# ('Earthquake', ['Central America', 'Western Asia', 'South America', 'Eastern Europe', 'Melanesia', 'Northern America', 'Western Europe', 'Russian Federation', 'Western Africa', 'Middle Africa', 'South-Eastern Asia', 'Northern Africa', 'Central Asia', 'Micronesia', 'Southern Europe', 'Eastern Asia', 'Australia and New Zealand', 'Caribbean', 'Polynesia', 'Eastern Africa', 'Southern Africa', 'Southern Asia', 'Northern Europe'])
#
# ('Flood', ['South-Eastern Asia', 'Western Africa', 'Caribbean', 'Eastern Africa', 'Southern Asia', 'Western Asia', 'Middle Africa', 'Northern Europe', 'Central America', 'Central Asia', 'Northern Africa', 'South America', 'Eastern Europe', 'Northern America', 'Western Europe', 'Eastern Asia', 'Australia and New Zealand', 'Southern Europe', 'Southern Africa', 'Melanesia', 'Russian Federation', 'Micronesia', 'Polynesia'])
#
# ('Mass movement (dry)', ['Southern Asia', 'Central America', 'Eastern Africa', 'Caribbean', 'Northern America', 'Central Asia', 'Melanesia', 'Western Europe', 'Eastern Asia', 'South America', 'South-Eastern Asia', 'Russian Federation', 'Western Africa', 'Northern Africa', 'Western Asia'])
#
# ('Landslide', ['Southern Europe', 'Southern Asia', 'Central America', 'Melanesia', 'Russian Federation', 'South-Eastern Asia', 'Middle Africa', 'Western Asia', 'Southern Africa', 'Western Europe', 'South America', 'Eastern Europe', 'Western Africa', 'Eastern Asia', 'Polynesia', 'Central Asia', 'Caribbean', 'Northern Europe', 'Eastern Africa', 'Northern America', 'Australia and New Zealand', 'Northern Africa'])
#
# ('Extreme temperature ', ['Western Europe', 'Eastern Asia', 'Southern Africa', 'Central Asia', 'Central America', 'Western Asia', 'Australia and New Zealand', 'Northern America', 'Northern Africa', 'Western Africa', 'South America', 'Southern Asia', 'Eastern Europe', 'Southern Europe', 'Northern Europe', 'South-Eastern Asia'])
#
# ('Complex Disasters', ['Russian Federation', 'Eastern Asia', 'Northern Africa', 'Eastern Africa', 'Western Asia', 'South-Eastern Asia', 'Central America', 'Western Africa', 'Southern Asia', 'Middle Africa'])
#
# ('Fog', ['Northern Europe'])
#
# ('Storm', ['Southern Asia', 'Micronesia', 'Melanesia', 'Eastern Africa', 'South America', 'Australia and New Zealand', 'Middle Africa', 'Eastern Asia', 'Central America', 'Southern Europe', 'Northern Europe', 'Central Asia', 'Polynesia', 'Western Europe', 'Western Africa', 'Eastern Europe', 'South-Eastern Asia', 'Northern America', 'Russian Federation', 'Caribbean', 'Southern Africa', 'Western Asia', 'Northern Africa'])
#
# ('Impact', ['Eastern Europe'])
#
# ('Industrial accident', ['Western Asia', 'Russian Federation', 'Central Asia', 'South-Eastern Asia', 'Australia and New Zealand', 'Central America', 'Northern America', 'Eastern Asia', 'Northern Africa', 'Southern Africa', 'Caribbean', 'Western Africa', 'Eastern Europe', 'Middle Africa', 'Melanesia', 'Southern Asia', 'South America', 'Northern Europe', 'Eastern Africa', 'Western Europe', 'Southern Europe'])
#
# ('Volcanic activity', ['Melanesia', 'Caribbean', 'Eastern Africa', 'Northern Europe', 'Micronesia', 'Australia and New Zealand', 'Northern America', 'Western Asia', 'Western Africa', 'Russian Federation', 'Eastern Asia', 'South-Eastern Asia', 'Middle Africa', 'Polynesia', 'Southern Europe', 'Central America', 'South America'])
#
# ('Miscellaneous accident', ['Northern Africa', 'Central America', 'Eastern Europe', 'Southern Asia', 'Caribbean', 'Western Asia', 'Southern Europe', 'Polynesia', 'Northern America', 'Middle Africa', 'Central Asia', 'Northern Europe', 'South America', 'South-Eastern Asia', 'Australia and New Zealand', 'Southern Africa', 'Western Africa', 'Russian Federation', 'Eastern Africa', 'Western Europe', 'Eastern Asia', 'Micronesia'])
#
#
# real	0m14.410s
# user	0m0.587s
# sys	0m0.223s

# %% [markdown]
# ### 3. What are the probabilities of getting injured or dying in a natural disaster of type T in the continent C during decade D (190x, 191x, 192x, ..., 199x, 200x, 201x)?

# %%
# %%file spark_3.py
import pyspark
sc = pyspark.SparkContext('local[*]')
try :
    # import input CSV file
    lines = sc.textFile('natural_disasters_BIG.csv')
    # separate each line by its columns and remove the empty lines in the columns of interest
    lines = lines.map( lambda line : line.split(",")).filter(lambda lines: len(lines[3])>0 and len(lines[5])>0 and \
                                                             len(lines[10])>0 and len(lines[11]) and len(lines[14])>0)
    
    # create a RDD with the decade, disaster type and continent as key and the deaths as value
    key_value_death = lines.map( lambda lines: (f"{lines[0][:len(lines[0])-1]}0,{lines[3]},{lines[5]}",f"{lines[10]}"))
    
    # create a RDD with the decade, disaster type and continent as key and the injured as value
    key_value_injured = lines.map( lambda lines: (f"{lines[0][:len(lines[0])-1]}0,{lines[3]},{lines[5]}",f"{lines[11]}"))
    
    # create a RDD with the decade, disaster type and continent as key and the total affected as value
    key_value_affected = lines.map( lambda lines: (f"{lines[0][:len(lines[0])-1]}0,{lines[3]},{lines[5]}",f"{lines[14]}"))
    
    # sum the number of deaths for each combination of decade, disaster type and continent
    total_deaths = key_value_death.reduceByKey(lambda v1, v2: int(v1)+int(v2))
    # do the same for the number of injured and total affected
    total_injured = key_value_injured.reduceByKey(lambda v1, v2: int(v1)+int(v2))
    total_affected = key_value_affected.reduceByKey(lambda v1, v2: int(v1)+int(v2))
    
    # join the RDD containing the summed deaths with the RDD containing the summed total affected 
    deaths_joint = total_deaths.join(total_affected)
    # for each key (combination of decade, disaster type and continent) divide the summed deaths by the summed total affected
    death_probs = deaths_joint.map(lambda x: (x[0], int(x[1][0])/int(x[1][1])))
    
    # do the same for the RDD containing the summed injured
    injured_joint = total_injured.join(total_affected)
    injured_probs = injured_joint.map(lambda x: (x[0], int(x[1][0])/int(x[1][1])))
    
    # join the two RDDs containing the probabilities 
    joint_probs = death_probs.join(injured_probs)
    
    # print all results
    for prob in joint_probs.collect():
        print(f"{prob}\n")
    sc.stop()
except Exception as e:
    print(e)
    sc.stop()
# Out:
# Overwriting spark_3.py

# %%
# !bash -c "time python spark_3.py"
# Out:
# 19/11/12 14:58:32 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# ('1920,Earthquake,Asia', (0.6777652879787639, 0.5234847966759577))
#
# ('1930,Industrial accident,Europe', (1.57791932059448, 1.0339702760084926))
#
# ('1960,Storm,Americas', (0.002320734689153696, 0.007446561348323535))
#
# ('1970,Miscellaneous accident,Europe', (0.4377650851099926, 0.9932986484193859))
#
# ('1970,Landslide,Asia', (0.06241701579116984, 0.004357073799548823))
#
# ('1970,Volcanic activity,Europe', (0.3935860058309038, 0.9628279883381924))
#
# ('1980,Earthquake,Europe', (0.010266170106388674, 0.008806389354177605))
#
# ('1980,Flood,Americas', (0.0003943165465470656, 0.0036641335095017203))
#
# ('1980,Storm,Asia', (0.00016827038923891282, 0.0005257816113193231))
#
# ('1980,Storm,Africa', (0.0011298922058910724, 0.007198632627589699))
#
# ('1980,Storm,Europe', (0.00024171292658492727, 0.004984369407244716))
#
# ('1980,Wildfire,Asia', (0.003502505795853077, 0.003974342796286509))
#
# ('1990,Volcanic activity,Asia', (0.0007859781533590825, 0.00024908914589791585))
#
# ('2000,Flood,Asia', (3.4957096004135086e-05, 0.00034726433161649226))
#
# ('2000,Storm,Africa', (0.0002745486079048286, 0.001440701410851506))
#
# ('2000,Earthquake,Oceania', (0.01565303066033368, 0.02804779125341538))
#
# ('2010,Landslide,Asia', (0.0015302702019956667, 0.0005499442805269815))
#
# ('2010,Industrial accident,Americas', (0.12410587928461791, 0.265583246753802))
#
# ('2010,Industrial accident,Africa', (1.052137974884756, 1.03862660944206))
#
# ('2010,Epidemic,Africa', (0.03197938149402255, 0.49991139607107876))
#
# ('1960,Landslide,Americas', (1.229535864978903, 0.9873417721518988))
#
# ('2000,Miscellaneous accident,Oceania', (2.492134831460674, 1.0404494382022471))
#
# ('1970,Wildfire,Africa', (0.00018511888293976924, 0.02451909775904438))
#
# ('1960,Earthquake,Africa', (0.15208279918884868, 0.2712414246426007))
#
# ('1970,Earthquake,Americas', (0.008381543194581592, 0.020752693937719374))
#
# ('1990,Earthquake,Africa', (0.0056590596498724745, 0.08570165716345961))
#
# ('1990,Industrial accident,Asia', (0.01237533682868583, 0.05021485194826394))
#
# ('1990,Earthquake,Oceania', (0.05082314894660674, 0.02208112869233968))
#
# ('1990,Storm,Africa', (0.00016722077936571635, 0.0009171691319895508))
#
# ('1990,Landslide,Europe', (0.5544312432493889, 0.5945085555113411))
#
# ('2000,Earthquake,Africa', (0.008524817690830315, 0.03516381191475392))
#
# ('2000,Flood,Americas', (0.00026891513806513994, 0.00017863740676948552))
#
# ('2000,Landslide,Europe', (0.01471345430715701, 0.017007068075080744))
#
# ('2000,Wildfire,Africa', (0.016702917093142273, 0.10753582395087001))
#
# ('2000,Landslide,Africa', (0.0049868944082412615, 0.002592615025765819))
#
# ('2010,Storm,Africa', (0.0007318456335851456, 0.0016917551930576773))
#
# ('1990,Wildfire,Oceania', (8.338285461406144e-05, 0.003818934741324014))
#
# ('2010,Industrial accident,Oceania', (18.912087912087912, 0.978021978021978))
#
# ('1930,Earthquake,Americas', (0.5168817378069559, 1.0585023858268818))
#
# ('1970,Transport accident,Oceania', (0.9885615251299826, 1.0954939341421144))
#
# ('1910,Transport accident,Americas', (0.11703810858460287, 0.6026518649591748))
#
# ('1920,Storm,Asia', (0.017491903516491103, 0.00026905528495035246))
#
# ('1930,Earthquake,Asia', (9.791967335903104, 0.2782339830833592))
#
# ('1940,Miscellaneous accident,Americas', (0.21556919182190915, 1.0140062188712473))
#
# ('1960,Flood,Africa', (0.0010453092279978842, 0.0009587975262270491))
#
# ('1970,Storm,Asia', (0.0008824520781711808, 0.0030651186912854594))
#
# ('1980,Earthquake,Asia', (0.0004248907878818757, 0.001370215432301503))
#
# ('1990,Transport accident,Americas', (0.8239662089183768, 0.9987463354420614))
#
# ('1990,Flood,Africa', (0.0007778881981806423, 0.022083170623328062))
#
# ('1990,Wildfire,Europe', (0.0011490976950879251, 0.001128221512633721))
#
# ('1990,Extreme temperature ,Oceania', (4.890466832699974e-06, 0.00018822017087509907))
#
# ('2000,Transport accident,Africa', (1.2236708664721634, 0.9983151652611806))
#
# ('2010,Flood,Oceania', (9.213971452045118e-05, 6.032957498362875e-05))
#
# ('2010,Transport accident,Africa', (0.7134613086260962, 0.997869607859876))
#
# ('1970,Extreme temperature ,Americas', (0.12280247446410589, 0.9835707092504675))
#
# ('1990,Volcanic activity,Americas', (3.373049829272383e-05, 0.0002554916852249174))
#
# ('1960,Volcanic activity,Americas', (0.0029223140040181817, 0.03968212942956293))
#
# ('1950,Storm,Asia', (2.085265817036133, 1.0516306661746757))
#
# ('1960,Miscellaneous accident,Europe', (1.6451703745423825, 1.0018304702900591))
#
# ('1970,Landslide,Europe', (1.480962714539357, 1.025843361609785))
#
# ('1970,Storm,Oceania', (0.0016288168759051903, 0.010917681037586401))
#
# ('1980,Miscellaneous accident,Africa', (0.05224734291478608, 0.9568002662284989))
#
# ('1980,Industrial accident,Europe', (0.04841895726752606, 0.8951053266225135))
#
# ('1990,Earthquake,Americas', (0.001271335552961268, 0.011534727632310221))
#
# ('2000,Storm,Americas', (0.0006737527403654734, 0.0007819679713218112))
#
# ('2000,Industrial accident,Asia', (0.03806920109589898, 0.03244112184497442))
#
# ('2000,Miscellaneous accident,Africa', (0.023251836861368155, 0.06084873003601185))
#
# ('2000,Flood,Oceania', (0.0025025301315668414, 0.009191277946453216))
#
# ('2000,Volcanic activity,Asia', (0.0001840433988935111, 0.0028544016918160627))
#
# ('2010,Wildfire,Asia', (0.002791294540556266, 0.0030033117729343266))
#
# ('2010,Flood,Europe', (0.0015526287650547473, 0.02894275701149803))
#
# ('2010,Storm,Americas', (2.93107292380825e-05, 8.210367235086954e-05))
#
# ('2010,Miscellaneous accident,Europe', (0.11323569462905829, 0.618948900243487))
#
# ('2010,Mass movement (dry),Asia', (28.475609756097562, 0.9634146341463414))
#
# ('1940,Earthquake,Americas', (0.06692976497509216, 0.2355170561732509))
#
# ('1950,Industrial accident,Europe', (7.038699690402477, 1.0092879256965945))
#
# ('1960,Earthquake,Asia', (0.03209096476510276, 0.018028113386734254))
#
# ('1960,Transport accident,Asia', (0.6109746109746109, 0.9876204876204876))
#
# ('1960,Volcanic activity,Asia', (0.015472350640373613, 0.027527736515692992))
#
# ('1970,Transport accident,Americas', (0.2032646067867944, 0.9909329254970505))
#
# ('1970,Industrial accident,Asia', (0.03729795644302712, 0.48040192362755835))
#
# ('1980,Industrial accident,Africa', (0.6797352014910985, 0.9814255414872421))
#
# ('1980,Mass movement (dry),Asia', (0.21330916232343833, 0.07860613842938792))
#
# ('1980,Epidemic,Oceania', (0.00384267131909631, 0.9026744109008193))
#
# ('1980,Earthquake,Oceania', (0.0012031909588263974, 0.014599582127515994))
#
# ('1990,Miscellaneous accident,Europe', (0.5013255065328536, 1.0019461802268088))
#
# ('1990,Miscellaneous accident,Africa', (0.28192790362767733, 0.6324205088348915))
#
# ('1990,Mass movement (dry),Americas', (0.030216209417059162, 0.012340847786893264))
#
# ('2000,Wildfire,Asia', (0.0028419051837088706, 0.030504345900459504))
#
# ('2000,Industrial accident,Europe', (0.04112242117188531, 0.13182124352775632))
#
# ('2000,Transport accident,Europe', (0.8237554119589666, 0.9652984540974868))
#
# ('2000,Epidemic,Africa', (0.06932738629671464, 0.8053697106612216))
#
# ('2010,Epidemic,Asia', (0.0030576292184339264, 0.9604606151567188))
#
# ('2010,Landslide,Africa', (0.01074169510335016, 0.0015941890485195501))
#
# ('2010,Industrial accident,Asia', (0.3053785009621817, 0.54437930622397))
#
# ('2010,Extreme temperature ,Asia', (0.00020011492515286267, 0.04296823173584475))
#
# ('1960,Transport accident,Americas', (0.17866727019948916, 0.09861295224546542))
#
# ('1980,Mass movement (dry),Europe', (0.11071375353896587, 0.011399195350916406))
#
# ('1940,Industrial accident,Europe', (0.23867614626548017, 1.0007711170401443))
#
# ('1960,Earthquake,Americas', (0.0035229232568021306, 0.00401652729600551))
#
# ('1970,Flood,Africa', (7.252156270563172e-05, 0.0027697393984044225))
#
# ('1970,Industrial accident,Africa', (0.11259198691741619, 1.1485690923957481))
#
# ('1970,Miscellaneous accident,Americas', (1.4442241379310345, 1.0378448275862069))
#
# ('1980,Landslide,Asia', (0.0066880152544056375, 0.019006418299013533))
#
# ('1980,Storm,Americas', (0.001171258214958015, 0.01232396224456087))
#
# ('1980,Transport accident,Europe', (0.408889449846357, 0.9385476487521663))
#
# ('1980,Industrial accident,Americas', (0.016774793082496388, 0.09198482519874802))
#
# ('1980,Extreme temperature ,Asia', (2.0641973258035047, 0.9772444149157047))
#
# ('1990,Earthquake,Europe', (0.004867226920550245, 0.012289482915733847))
#
# ('1990,Miscellaneous accident,Asia', (0.06849336502397158, 0.11793747181699862))
#
# ('1990,Miscellaneous accident,Americas', (0.2699227202472952, 0.9030161183484213))
#
# ('1990,Epidemic,Africa', (0.02801645776350256, 0.9999868292982046))
#
# ('2000,Wildfire,Americas', (6.11530977224146e-05, 0.00036873244940252526))
#
# ('2000,Landslide,Asia', (0.005920322878979527, 0.0014830782687961749))
#
# ('2000,Extreme temperature ,Asia', (0.002269580916084389, 0.01195991981530825))
#
# ('2010,Storm,Asia', (0.00010230878694937686, 0.0004481039282969004))
#
# ('2010,Miscellaneous accident,Americas', (0.7092388300577013, 0.6072447107200495))
#
# ('2010,Transport accident,Oceania', (8.315555555555555, 1.0622222222222222))
#
# ('1960,Wildfire,Oceania', (0.020892693403570528, 0.031280577487584386))
#
# ('1990,Volcanic activity,Oceania', (4.972960562972289e-05, 0.000182238283963922))
#
# ('1990,Miscellaneous accident,Oceania', (8.522206124721764e-05, 0.00031344385238383436))
#
# ('1970,Storm,Europe', (0.0475396163469558, 0.8990825688073395))
#
# ('1900,Miscellaneous accident,Europe', (8.976744186046512, 0.872093023255814))
#
# ('1940,Earthquake,Asia', (0.12364908170030355, 0.468122678516064))
#
# ('1960,Flood,Asia', (0.00012188671006580714, 0.0057453475781144925))
#
# ('1960,Miscellaneous accident,Asia', (0.008974717139265261, 0.09361519436661381))
#
# ('1970,Storm,Americas', (0.001148996395686747, 0.00450760893410219))
#
# ('1980,Volcanic activity,Americas', (0.4314416159798649, 0.11188228627802656))
#
# ('1980,Landslide,Americas', (0.02462316229190113, 0.06718737947225908))
#
# ('1990,Storm,Asia', (0.0010402662275652704, 0.0015336767343951793))
#
# ('1990,Flood,Americas', (0.008695159527785573, 0.0017519070137268743))
#
# ('1990,Industrial accident,Americas', (0.01972751860616979, 0.15091490948162076))
#
# ('1990,Transport accident,Africa', (0.840254640802536, 0.9835109644259493))
#
# ('2000,Flood,Africa', (0.0011326454551475404, 0.0014232237978404198))
#
# ('2000,Miscellaneous accident,Asia', (0.07163552282335142, 0.16542320569003421))
#
# ('2000,Landslide,Americas', (0.049337942091520454, 0.020453297659276674))
#
# ('2010,Flood,Asia', (0.0001325946337801019, 0.00033368549518249095))
#
# ('2010,Earthquake,Europe', (0.001967680848666854, 0.007594143518002664))
#
# ('1990,Epidemic,Americas', (0.006753638148499582, 0.3158738288717079))
#
# ('2000,Transport accident,Oceania', (0.45937961595273263, 0.96602658788774))
#
# ('1930,Earthquake,Europe', (0.3464745755627234, 1.0076980417017898))
#
# ('1940,Transport accident,Americas', (2.0690921228304404, 1.0767690253671562))
#
# ('1950,Transport accident,Americas', (0.2718140068886338, 1.009216736828677))
#
# ('1950,Earthquake,Asia', (0.3018796683109125, 0.5103879318392894))
#
# ('1960,Transport accident,Africa', (0.44044924748217723, 1.0338915921692882))
#
# ('1970,Landslide,Americas', (0.4244453816954871, 1.0064276676507802))
#
# ('1970,Transport accident,Africa', (0.2845701462508705, 0.9674998065464675))
#
# ('1980,Transport accident,Africa', (0.573790564538363, 1.005911354016315))
#
# ('1980,Volcanic activity,Africa', (0.1948828706044419, 0.04483304389879317))
#
# ('1990,Mass movement (dry),Asia', (0.05017212920223248, 0.028255321872275065))
#
# ('1990,Flood,Oceania', (0.000171074218583973, 0.0016698331335696496))
#
# ('2000,Industrial accident,Africa', (0.01747234934743242, 0.016945628223497093))
#
# ('2000,Mass movement (dry),Asia', (0.1435527760538502, 0.04554351458442736))
#
# ('2010,Volcanic activity,Asia', (0.002503226852415696, 0.04506896715261479))
#
# ('2010,Miscellaneous accident,Asia', (0.09542414947201724, 0.171081050509352))
#
# ('2010,Transport accident,Asia', (0.9128602685562602, 0.9185112786965358))
#
# ('2010,Earthquake,Oceania', (0.00042139540531057473, 0.0022181287926647986))
#
# ('1950,Industrial accident,Asia', (0.395373238732887, 1.0430365410879052))
#
# ('1990,Extreme temperature ,Asia', (0.45940624053317175, 0.9188124810663435))
#
# ('1950,Earthquake,Africa', (0.6410115448048378, 0.9692138537658054))
#
# ('1960,Flood,Americas', (0.0034235229634452737, 0.013516804098518425))
#
# ('1960,Storm,Africa', (0.0015391278737374612, 0.0009133590894128653))
#
# ('1970,Miscellaneous accident,Africa', (0.6772453189463662, 1.0555379244684227))
#
# ('1970,Flood,Europe', (0.000877887270932497, 0.005904222233918559))
#
# ('1980,Flood,Africa', (0.0008442102710958125, 0.002110972744079035))
#
# ('1980,Wildfire,Europe', (0.1260963335729691, 1.0122214234363767))
#
# ('1980,Landslide,Europe', (0.018684434584950907, 0.03590556757615287))
#
# ('2000,Wildfire,Europe', (0.01298247292558261, 0.042207756365201965))
#
# ('2000,Storm,Oceania', (0.0008101317323129028, 0.004575168788898419))
#
# ('2000,Wildfire,Oceania', (0.015375452141438184, 0.04933701586063412))
#
# ('2010,Transport accident,Americas', (0.5848376887003497, 0.9910351798763816))
#
# ('2010,Wildfire,Americas', (0.0020110823183811227, 0.021018692891451408))
#
# ('2010,Earthquake,Africa', (9.215415079559048e-05, 0.004854213877873734))
#
# ('1950,Mass movement (dry),Americas', (0.001296846528883563, 0.0027824745145033406))
#
# ('1920,Transport accident,Europe', (0.2579578338156263, 0.8865233567589913))
#
# ('1960,Miscellaneous accident,Americas', (0.02489434951788843, 0.05693510324624493))
#
# ('1970,Volcanic activity,Asia', (0.009993697536022727, 0.04325001705847351))
#
# ('1980,Industrial accident,Asia', (0.010215489958293276, 0.2819862081450125))
#
# ('1980,Transport accident,Asia', (1.0761469038379325, 0.9731186478309033))
#
# ('1990,Transport accident,Europe', (0.5247410462129524, 0.9601975582783704))
#
# ('1990,Landslide,Americas', (0.006270836945896832, 0.0032803931332393006))
#
# ('1990,Industrial accident,Africa', (1.5007899510425404, 1.0040180225867483))
#
# ('2000,Extreme temperature ,Europe', (0.021961402715777917, 0.14408423635526357))
#
# ('2000,Storm,Asia', (0.0005012495723009594, 0.0007352422996894461))
#
# ('2000,Miscellaneous accident,Americas', (0.30337733223690844, 0.6639338201519609))
#
# ('2000,Transport accident,Asia', (0.31628542595510895, 0.2953642529113893))
#
# ('2000,Volcanic activity,Americas', (6.191644036395339e-05, 5.4846708627851076e-05))
#
# ('2010,Landslide,Americas', (0.009757545333679984, 0.006648441153985191))
#
# ('2010,Extreme temperature ,Europe', (0.0031868874964764865, 0.043254130656891064))
#
# ('2010,Epidemic,Americas', (0.013004421807343165, 0.5086600157534389))
#
# ('1910,Earthquake,Asia', (0.5596336192994904, 0.9267453611129028))
#
# ('1990,Landslide,Africa', (0.055755787233013235, 0.07842093805181297))
#
# ('2000,Volcanic activity,Africa', (0.0017851149777560762, 0.0030994088914565476))
#
# ('1910,Storm,Americas', (0.011396990133858885, 0.08069502956226156))
#
# ('1930,Storm,Americas', (0.15995043862107824, 0.5427948420518526))
#
# ('1950,Earthquake,Americas', (0.7351241913979557, 1.0026171547084095))
#
# ('1950,Storm,Americas', (0.007092801967100166, 0.007836880199220497))
#
# ('1960,Earthquake,Europe', (0.002965364388698992, 0.012681697279744737))
#
# ('1970,Transport accident,Europe', (0.6618325642715887, 1.0042622999940074))
#
# ('1970,Industrial accident,Americas', (0.04073292290749311, 0.30254702509940684))
#
# ('1970,Industrial accident,Europe', (0.034943468753370795, 0.13326273056217455))
#
# ('1980,Earthquake,Americas', (0.003361154365176779, 0.012195691614758636))
#
# ('1980,Flood,Europe', (0.0021189173997897847, 0.00714332579501886))
#
# ('1990,Storm,Americas', (0.0023259210335369713, 0.0019320577876410867))
#
# ('1990,Industrial accident,Europe', (0.6864414347373121, 1.0183658282482513))
#
# ('2000,Extreme temperature ,Americas', (0.000198456416216481, 0.9277233470635556))
#
# ('2000,Earthquake,Europe', (0.004247980481469933, 0.01813126629356872))
#
# ('2000,Flood,Europe', (0.00042525307084864786, 0.0018920067328105957))
#
# ('2010,Earthquake,Americas', (0.023354029643273256, 0.03165464760813311))
#
# ('2010,Flood,Africa', (0.0001944771430498516, 0.000548667980702347))
#
# ('1910,Landslide,Americas', (2.6968130921619293, 1.0645994832041343))
#
# ('1960,Earthquake,Oceania', (0.007142857142857143, 0.042179353493222105))
#
# ('1990,Industrial accident,Oceania', (0.18857142857142858, 1.0150375939849625))
#
# ('1910,Transport accident,Europe', (0.9500691180536356, 0.9187724633674316))
#
# ('1930,Transport accident,Europe', (0.6386601587242445, 0.918998472372294))
#
# ('1960,Storm,Asia', (0.0029647648529572052, 0.034779096843938644))
#
# ('1960,Flood,Europe', (0.005153546095823997, 0.1521045320383552))
#
# ('1970,Miscellaneous accident,Asia', (0.011971710720550305, 0.006999955198316594))
#
# ('1980,Miscellaneous accident,Europe', (0.15029266264615615, 0.43287444702409034))
#
# ('1980,Flood,Asia', (9.110116938603796e-05, 0.0004154651010844999))
#
# ('1980,Miscellaneous accident,Asia', (0.016318074471587757, 0.03885688158293417))
#
# ('1980,Transport accident,Americas', (0.42237238459659693, 0.8187989654243827))
#
# ('1990,Flood,Europe', (0.0018842351332825217, 0.01989228558808357))
#
# ('1990,Wildfire,Asia', (0.008075874333135743, 0.0032475076790429488))
#
# ('2010,Wildfire,Europe', (0.013612331763054214, 0.1560159543604663))
#
# ('2010,Flood,Americas', (0.00022827105728594782, 0.0010880394084540163))
#
# ('2010,Industrial accident,Europe', (0.017933345342032732, 0.03318226814575585))
#
# ('2010,Miscellaneous accident,Africa', (0.04972600613985559, 0.1515973159632506))
#
# ('2010,Transport accident,Europe', (0.7803219007472696, 0.7046113559430287))
#
# ('2010,Extreme temperature ,Africa', (0.001199044570834034, 0.0008963182270359312))
#
# ('1990,Transport accident,Oceania', (0.2653083225528245, 0.6319534282018111))
#
# ('2000,Landslide,Oceania', (0.05778737981237105, 0.038362723344622214))
#
# ('1940,Storm,Americas', (0.041321220673840184, 0.9206209207973187))
#
# ('2000,Extreme temperature ,Africa', (0.024279210925644917, 1.009441915359973))
#
# ('1940,Transport accident,Europe', (0.18310031886190828, 0.9616752514103507))
#
# ('1950,Transport accident,Europe', (0.24351834989888146, 1.0084249470445592))
#
# ('1950,Earthquake,Europe', (0.2707413432488961, 1.0631652335579829))
#
# ('1960,Transport accident,Europe', (0.5221615057680632, 1.0916818457802064))
#
# ('1970,Flood,Americas', (0.0008067236705181307, 0.008671045373558957))
#
# ('1970,Flood,Asia', (0.0001949493833017736, 0.0006039625755807353))
#
# ('1970,Earthquake,Europe', (0.0020126049834324295, 0.009166557296181533))
#
# ('1970,Transport accident,Asia', (0.17078482230499703, 0.47617190293243883))
#
# ('1980,Earthquake,Africa', (0.0029698037554401987, 0.009863616447156156))
#
# ('1980,Miscellaneous accident,Americas', (0.06024462127910404, 0.46970527556734454))
#
# ('1980,Wildfire,Oceania', (0.12246403541128735, 1.0555145702692734))
#
# ('1990,Earthquake,Asia', (0.005014679089251864, 0.015963159041781052))
#
# ('1990,Flood,Asia', (2.6021077611030833e-05, 0.0007649472680945033))
#
# ('1990,Storm,Oceania', (2.0248886952555557e-05, 0.00026237026765967524))
#
# ('1990,Transport accident,Asia', (0.9885681978665953, 0.9992152805635904))
#
# ('1990,Wildfire,Americas', (0.00044162324677489277, 0.007383122233726972))
#
# ('1990,Extreme temperature ,Europe', (0.0008222452367367648, 0.001392803998066437))
#
# ('1990,Landslide,Oceania', (0.08646399839603018, 0.027242425001879653))
#
# ('1990,Wildfire,Africa', (0.0010917260875068563, 0.0015980338382346737))
#
# ('2000,Earthquake,Americas', (0.000660423613865409, 0.004543877517012497))
#
# ('2000,Storm,Europe', (0.0014180780338038327, 0.019978660185810078))
#
# ('2000,Miscellaneous accident,Europe', (0.056270389641479714, 0.17746469142705198))
#
# ('2000,Industrial accident,Americas', (0.018485510944549814, 0.08528395400267615))
#
# ('2000,Mass movement (dry),Africa', (0.13702939767068775, 0.09683938579494551))
#
# ('2010,Storm,Oceania', (0.00010519709294337159, 0.000301956731534309))
#
# ('1900,Mass movement (dry),Americas', (2.3806794924273436, 0.9582480556692591))
#
# ('1910,Volcanic activity,Asia', (7.011273957158963, 0.9954904171364148))
#
# ('1920,Industrial accident,Europe', (0.39007808821221157, 1.049697849631141))
#
# ('1960,Landslide,Asia', (0.1777033910638917, 0.05894338524232281))
#
# ('2010,Wildfire,Oceania', (0.005557354052012517, 0.5887558001510736))
#
# ('1930,Transport accident,Americas', (1.2264, 1.0632))
#
# ('1940,Miscellaneous accident,Europe', (0.10150808884014258, 1.0314230874691528))
#
# ('1950,Storm,Oceania', (0.02475889882517973, 0.9115553217604769))
#
# ('1970,Storm,Africa', (3.761521412542663e-05, 0.00016644691239583136))
#
# ('1970,Earthquake,Asia', (0.12957425870488146, 0.10104277484958675))
#
# ('1980,Storm,Oceania', (0.00011456954516212395, 0.0007941423423614779))
#
# ('1990,Landslide,Asia', (0.007882327478509239, 0.0036377401755026627))
#
# ('1990,Storm,Europe', (6.554199622104435e-05, 0.00015020981160807033))
#
# ('2000,Earthquake,Asia', (0.004018167421162098, 0.013538982112314383))
#
# ('2000,Transport accident,Americas', (0.7781085775486535, 0.8513898214791097))
#
# ('2000,Epidemic,Asia', (0.09874717920784375, 0.9998443700879309))
#
# ('2000,Extreme temperature ,Oceania', (0.17489648033126293, 0.9542517006802721))
#
# ('2010,Earthquake,Asia', (0.0019570386814141785, 0.00897466044556209))
#
# ('2010,Storm,Europe', (0.00026567300994391826, 0.001975959179484301))
#
# ('2010,Landslide,Europe', (2.4918032786885247, 1.0))
#
# ('2010,Volcanic activity,Americas', (0.00025738525354455184, 1.6460150190952047e-05))
#
# ('1970,Earthquake,Oceania', (0.00546557911908646, 0.0007412724306688418))
#
#
# real	0m25.389s
# user	0m0.631s
# sys	0m0.206s

# %% [markdown]
# ### 4. Optional Exercise. What is the mean total damage and most costly disaster's expanses of a certain disaster subgroup in each country?

# %%
# %%file spark_4.py
import pyspark
sc = pyspark.SparkContext('local[*]')
try :
    # import input CSV file
    lines = sc.textFile('natural_disasters_BIG.csv')
    # separate each line by its columns and remove the empty lines in the column of interest
    lines = lines.map( lambda line : line.split(",")).filter(lambda lines: len(lines[15])>0)
    
    # create a RDD with the country and disaster subgroup as key and the total damage as value
    key_value_damage = lines.map( lambda lines: (f"{lines[8]},{lines[2]}",f"{lines[15]}"))
    
    # create a RDD with the country and disaster subgroup as key and the occurrences as value
    key_value_occcurrences = lines.map( lambda lines: (f"{lines[8]},{lines[2]}",f"{lines[9]}"))
    
    # sum the total damage for each combination of country and disaster subgroup
    total_damage = key_value_damage.reduceByKey(lambda v1, v2: float(v1)+float(v2))
    # do the same for the occurrences
    total_occurrences = key_value_occcurrences.reduceByKey(lambda v1, v2: int(v1)+int(v2))
    
    # join the RDD containing the total damage with the RDD containing the total occurrences
    damage_occurrences_joint = total_damage.join(total_occurrences)
    # for each key (combination of country and disaster subgroup) divide the total damage by the total occurrences
    mean_damage = damage_occurrences_joint.map(lambda x: (x[0], float(x[1][0])/float(x[1][1])))
    
    # find the maximum damage for each combination of country and disaster subgroup
    max_damage = key_value_damage.reduceByKey(lambda v1, v2: max(float(v1), float(v2)))
    
    # join the two RDDs containing the damages
    joint_rdd = mean_damage.join(max_damage)
    
    # print all results
    for damage in joint_rdd.collect():
        print(f"{damage}\n")
    sc.stop()
except Exception as e:
    print(e)
    sc.stop()
# Out:
# Overwriting spark_4.py

# %%
# !bash -c "time python spark_4.py"
# Out:
# 19/11/14 11:48:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# ('United States of America (the),Hydrological', (571690.463576159, 12600000.0))
#
# ('Ethiopia,Geophysical', (3535.0, 6750.0))
#
# ('Chile,Geophysical', (1290252.5, 30000000.0))
#
# ('Hong Kong,Meteorological', (58578.71428571428, 755500.0))
#
# ('Italy,Geophysical', (2108498.153846154, 20000000.0))
#
# ('Taiwan (Province of China),Meteorological', (100978.39344262295, 1300000.0))
#
# ('Philippines (the),Meteorological', (68841.74198757764, 10136563.0))
#
# ('Canada,Climatological', (1388409.0909090908, 4200000.0))
#
# ('Turkey,Technological', (139000.0, 178000.0))
#
# ('Germany Fed Rep,Meteorological', (348300.0, 1300000.0))
#
# ('New Zealand,Geophysical', (3585958.625, 18000000.0))
#
# ('Jamaica,Meteorological', (115790.52173913043, 1000000.0))
#
# ('Turkey,Geophysical', (705297.1428571428, 21000000.0))
#
# ('Romania,Geophysical', (1005000.0, 2000000.0))
#
# ('Soviet Union,Geophysical', (1405816.6666666667, 14000000.0))
#
# ('Cuba,Meteorological', (553691.0769230769, 3572000.0))
#
# ('Germany Fed Rep,Technological', (13750.0, 35000.0))
#
# ('Ecuador,Geophysical', (307997.9166666667, 2000000.0))
#
# ('Antigua and Barbuda,Meteorological', (132266.66666666666, 350000.0))
#
# ('El Salvador,Geophysical', (681300.0, 1848500.0))
#
# ('Vanuatu,Meteorological', (82081.25, 449400.0))
#
# ('Fiji,Meteorological', (40267.357142857145, 600000.0))
#
# ('Greece,Geophysical', (515153.3333333333, 4200000.0))
#
# ('Netherlands (the),Hydrological', (227650.0, 530000.0))
#
# ('Mexico,Meteorological', (338806.40625, 7910000.0))
#
# ('Mexico,Geophysical', (911125.0, 8300000.0))
#
# ('Anguilla,Meteorological', (47465.0, 200000.0))
#
# ('Bangladesh,Meteorological', (196761.875, 2300000.0))
#
# ('Spain,Hydrological', (381864.5652173913, 3900000.0))
#
# ('Guam,Meteorological', (111238.33333333333, 300000.0))
#
# ('Libya,Geophysical', (5000.0, '5000'))
#
# ('Yugoslavia,Geophysical', (193100.0, 600000.0))
#
# ('Bahamas (the),Meteorological', (220006.66666666666, 1550000.0))
#
# ('Brazil,Hydrological', (107847.56666666667, 2000000.0))
#
# ('Bangladesh,Hydrological', (394436.36363636365, 4300000.0))
#
# ('Fiji,Hydrological', (23280.875, 89000.0))
#
# ('Viet Nam,Meteorological', (128354.32911392405, 2985000.0))
#
# ('Pakistan,Meteorological', (346607.2, 1620000.0))
#
# ('Madagascar,Technological', (50.0, '50'))
#
# ('Myanmar,Technological', (15894.35294117647, 96000.0))
#
# ('Dominican Republic (the),Climatological', (3000.0, 5000.0))
#
# ('Philippines (the),Geophysical', (26940.636363636364, 370500.0))
#
# ('Morocco,Hydrological', (41275.0, 200000.0))
#
# ('Honduras,Hydrological', (30284.615384615383, 100000.0))
#
# ('Mexico,Hydrological', (254133.33333333334, 3000000.0))
#
# ('Ecuador,Hydrological', (129473.125, 1000000.0))
#
# ('Paraguay,Hydrological', (12069.625, 82000.0))
#
# ('Japan,Hydrological', (1177252.380952381, 9500000.0))
#
# ('Korea (the Republic of),Hydrological', (110744.10344827586, 1480000.0))
#
# ('Malaysia,Hydrological', (87888.23529411765, 968000.0))
#
# ('Jordan,Hydrological', (1133.3333333333333, 1400.0))
#
# ('Nepal,Geophysical', (1096000.0, 5174000.0))
#
# ('Algeria,Hydrological', (102927.8, 779000.0))
#
# ('Hong Kong,Hydrological', (21158.0, 50000.0))
#
# ('Mongolia,Hydrological', (8454.666666666666, 25000.0))
#
# ('Senegal,Hydrological', (10887.0, 40979.0))
#
# ('Panama,Hydrological', (3400.0, 15000.0))
#
# ('Argentina,Hydrological', (395614.64285714284, 1800000.0))
#
# ('Indonesia,Hydrological', (51502.16296296296, 3006000.0))
#
# ("Lao People's Democratic Republic (the),Hydrological", (17065.8, 121000.0))
#
# ('Viet Nam,Hydrological', (60409.194444444445, 517700.0))
#
# ('India,Meteorological', (304882.3058823529, 7000000.0))
#
# ('Japan,Technological', (61000.0, 160500.0))
#
# ('Uganda,Climatological', (900.0, 1600.0))
#
# ('Colombia,Geophysical', (301242.36363636365, 1857366.0))
#
# ('Venezuela (Bolivarian Republic of),Geophysical', (27400.0, 81000.0))
#
# ('Malawi,Hydrological', (60355.57142857143, 390000.0))
#
# ('Mozambique,Hydrological', (69478.57142857143, 419200.0))
#
# ('Peru,Hydrological', (252735.29411764705, 3200000.0))
#
# ('Syrian Arab Republic,Hydrological', (22000.0, 39000.0))
#
# ('Portugal,Hydrological', (248850.0, 1350000.0))
#
# ('France,Meteorological', (866529.4444444445, 12000000.0))
#
# ('Saint Vincent and the Grenadines,Meteorological', (11183.333333333334, 25000.0))
#
# ('United Kingdom of Great Britain and Northern Ireland (the),Technological', (164675.0, 1200000.0))
#
# ('Viet Nam,Technological', (1125.0, 2000.0))
#
# ('Gambia (the),Climatological', (350.0, 500.0))
#
# ('Haiti,Climatological', (29000.0, 84000.0))
#
# ('Jamaica,Climatological', (3250.0, 6000.0))
#
# ('Chile,Climatological', (191000.0, 550000.0))
#
# ('Australia,Geophysical', (336558.3333333333, 1000000.0))
#
# ('Ethiopia,Hydrological', (1925.6, 6200.0))
#
# ('United Republic of Tanzania,Hydrological', (1631.6666666666667, 3510.0))
#
# ('South Africa,Hydrological', (107159.42105263157, 765305.0))
#
# ('Ghana,Hydrological', (30050.0, 74700.0))
#
# ('Nicaragua,Hydrological', (683.3333333333334, 1500.0))
#
# ('Nepal,Hydrological', (51561.6, 595000.0))
#
# ('United Kingdom of Great Britain and Northern Ireland (the),Meteorological', (550220.3703703703, 4790000.0))
#
# ('Guatemala,Technological', (20.0, '20'))
#
# ('Mauritania,Climatological', (29750.0, 34000.0))
#
# ('Iraq,Climatological', (2000.0, '2000'))
#
# ('Indonesia,Geophysical', (177758.88095238095, 4451600.0))
#
# ('Costa Rica,Hydrological', (31000.0, 250000.0))
#
# ('Guatemala,Meteorological', (266888.8888888889, 988300.0))
#
# ('Morocco,Technological', (500.0, '500'))
#
# ('Brazil,Climatological', (1402387.5, 5000000.0))
#
# ('Benin,Hydrological', (2078.75, 4800.0))
#
# ('Barbados,Hydrological', (500.0, '500'))
#
# ('Pakistan,Technological', (33523.333333333336, 100000.0))
#
# ('Kenya,Climatological', (1500.0, '1500'))
#
# ('Ghana,Climatological', (100.0, '100'))
#
# ('Guyana,Hydrological', (211433.33333333334, 465100.0))
#
# ('Australia,Hydrological', (274198.21428571426, 7409000.0))
#
# ('Spain,Meteorological', (406638.46153846156, 1900000.0))
#
# ('Nicaragua,Meteorological', (195242.22222222222, 987700.0))
#
# ('Honduras,Climatological', (8500.0, 10000.0))
#
# ('Indonesia,Climatological', (1048920.0, 8000000.0))
#
# ('Nepal,Climatological', (8100.0, 10000.0))
#
# ('Botswana,Hydrological', (2525.0, 5000.0))
#
# ('Haiti,Hydrological', (791.8, 2000.0))
#
# ('Philippines (the),Hydrological', (33724.94736842105, 2231988.0))
#
# ('Haiti,Technological', (550.0, 2000.0))
#
# ('Iceland,Geophysical', (16300.0, 24700.0))
#
# ('Pakistan,Geophysical', (409981.1538461539, 5200000.0))
#
# ('Cambodia,Technological', (600.0, '600'))
#
# ('Philippines (the),Biological', (925.0, '925'))
#
# ('Yemen Arab Rep,Hydrological', (12700.0, '12700'))
#
# ('Brazil,Meteorological', (229714.2857142857, 600000.0))
#
# ('Guatemala,Geophysical', (243410.0, 1000000.0))
#
# ('China,Geophysical', (929391.3801652893, 85492000.0))
#
# ('Argentina,Geophysical', (92000.0, 104000.0))
#
# ('Tonga,Geophysical', (5350.0, 9500.0))
#
# ('Djibouti,Hydrological', (1906.3333333333333, 2500.0))
#
# ('Sweden,Hydrological', (62266.666666666664, 170000.0))
#
# ('United Kingdom of Great Britain and Northern Ireland (the),Hydrological', (864278.0769230769, 8448000.0))
#
# ('Germany Fed Rep,Geophysical', (150000.0, '150000'))
#
# ('Sudan (the),Hydrological', (79742.85714285714, 300000.0))
#
# ('Myanmar,Climatological', (11000.0, '11000'))
#
# ('Egypt,Hydrological', (51666.666666666664, 140000.0))
#
# ('Spain,Climatological', (1676763.5, 4500000.0))
#
# ('Turkey,Hydrological', (138843.75, 1000000.0))
#
# ('Réunion,Meteorological', (50800.0, 85000.0))
#
# ('Grenada,Meteorological', (299933.3333333333, 889000.0))
#
# ('Yemen P Dem Rep,Hydrological', (260050.0, 975000.0))
#
# ('Switzerland,Meteorological', (188011.81818181818, 1500000.0))
#
# ('Niger (the),Technological', (16000.0, '16000'))
#
# ('Benin,Climatological', (651.0, '651'))
#
# ('Nigeria,Climatological', (71103.0, '71103'))
#
# ('Bolivia (Plurinational State of),Climatological', (303120.0, 917200.0))
#
# ('Portugal,Climatological', (645237.3333333334, 1730000.0))
#
# ('Fiji,Climatological', (30000.0, '30000'))
#
# ('Yugoslavia,Climatological', (600000.0, 1000000.0))
#
# ('Belgium,Geophysical', (75000.0, 100000.0))
#
# ('Mozambique,Meteorological', (14672.222222222223, 75000.0))
#
# ('Swaziland,Meteorological', (54152.0, '54152'))
#
# ('Mexico,Technological', (228912.5, 1000000.0))
#
# ('Costa Rica,Technological', (6250.0, 10000.0))
#
# ('Italy,Technological', (3000.0, '3000'))
#
# ('Nigeria,Hydrological', (43877.23809523809, 500000.0))
#
# ('Bermuda,Meteorological', (88375.0, 300000.0))
#
# ('Turks and Caicos Islands (the),Meteorological', (200001.0, 500000.0))
#
# ('Hungary,Climatological', (328000.0, 500000.0))
#
# ('Brazil,Geophysical', (5000.0, '5000'))
#
# ('Iran (Islamic Republic of),Hydrological', (249430.56, 3580000.0))
#
# ('China,Meteorological', (477128.71532846714, 21100000.0))
#
# ('Solomon Islands,Meteorological', (7333.333333333333, 20000.0))
#
# ('Soviet Union,Technological', (2800000.0, '2800000'))
#
# ('New Zealand,Technological', (3300.0, '3300'))
#
# ('Argentina,Climatological', (1206666.6666666667, 3400000.0))
#
# ('Maldives,Hydrological', (6000.0, '6000'))
#
# ('Czechoslovakia,Hydrological', (1000.0, '1000'))
#
# ('Greece,Meteorological', (173250.0, 350000.0))
#
# ('Cook Islands (the),Meteorological', (25000.0, '25000'))
#
# ('Costa Rica,Meteorological', (93731.66666666667, 200000.0))
#
# ('Trinidad and Tobago,Technological', (8500.0, 15000.0))
#
# ('Portugal,Technological', (250000.0, '250000'))
#
# ('Malawi,Geophysical', (28000.0, '28000'))
#
# ('Montserrat,Meteorological', (130000.0, 240000.0))
#
# ('Netherlands Antilles,Meteorological', (525000.0, 1000000.0))
#
# ('Saint Kitts and Nevis,Meteorological', (140880.0, 400000.0))
#
# ('Virgin Island (U.S.),Meteorological', (247560.0, 936000.0))
#
# ('South Africa,Technological', (67700.0, '67700'))
#
# ('United States of America (the),Technological', (1385975.0, 20000000.0))
#
# ('Swaziland,Climatological', (1739.0, '1739'))
#
# ('Mongolia,Climatological', (911400.0, 1712800.0))
#
# ('Finland,Meteorological', (5000.0, '10000'))
#
# ('Sweden,Meteorological', (742500.0, 2800000.0))
#
# ('Austria,Meteorological', (141942.85714285713, 500000.0))
#
# ('Netherlands (the),Meteorological', (270783.94444444444, 1750000.0))
#
# ('Barbados,Technological', (15000.0, '15000'))
#
# ('Grenada,Technological', (6000.0, '6000'))
#
# ('Mozambique,Climatological', (50000.0, '50000'))
#
# ('South Africa,Climatological', (551666.6666666666, 1200000.0))
#
# ("Lao People's Democratic Republic (the),Climatological", (1000.0, '1000'))
#
# ('Nicaragua,Climatological', (32666.666666666668, 80000.0))
#
# ('Myanmar,Hydrological', (36807.857142857145, 119000.0))
#
# ('Nepal,Technological', (630.0, 1000.0))
#
# ('Lithuania,Climatological', (139236.5, 225573.0))
#
# ('Germany,Geophysical', (31000.0, 50000.0))
#
# ('Germany,Hydrological', (2196910.0, 12900000.0))
#
# ('Albania,Hydrological', (8393.25, 17500.0))
#
# ('Puerto Rico,Hydrological', (173000.0, 200000.0))
#
# ('Russian Federation (the),Hydrological', (73160.87719298246, 1000000.0))
#
# ('Jordan,Meteorological', (400000.0, '400000'))
#
# ('New Zealand,Meteorological', (44800.0, 200000.0))
#
# ('Ukraine,Meteorological', (48657.142857142855, 120000.0))
#
# ('Senegal,Technological', (9750.0, 18700.0))
#
# ('Libya,Technological', (8400.0, '8400'))
#
# ('Trinidad and Tobago,Hydrological', (1885.0, 3700.0))
#
# ('Ireland,Hydrological', (181500.0, 325000.0))
#
# ('Yemen,Hydrological', (402875.0, 1210000.0))
#
# ('Mongolia,Meteorological', (50666.666666666664, 80000.0))
#
# ('Lithuania,Meteorological', (11700.0, 30000.0))
#
# ('Eritrea,Meteorological', (5165.0, '5165'))
#
# ('Iran (Islamic Republic of),Meteorological', (9513.333333333334, 15000.0))
#
# ('Papua New Guinea,Meteorological', (1500.0, '1500'))
#
# ('Puerto Rico,Climatological', (2000.0, '2000'))
#
# ('Costa Rica,Climatological', (12000.0, 23000.0))
#
# ('Cambodia,Climatological', (69000.0, 100000.0))
#
# ('Moldova (the Republic of),Hydrological', (72516.8, 300000.0))
#
# ('Russian Federation (the),Meteorological', (100067.64705882352, 1000000.0))
#
# ('Papua New Guinea,Technological', (12000.0, '12000'))
#
# ('Israel,Climatological', (227500.0, 520000.0))
#
# ('Cyprus,Geophysical', (4340.0, '4340'))
#
# ('Libya,Hydrological', (24650.0, 42200.0))
#
# ('Azerbaijan,Hydrological', (19240.0, 55000.0))
#
# ('Iceland,Hydrological', (2894.5, '5789'))
#
# ('Virgin Island (British),Meteorological', (753000.0, 3000000.0))
#
# ('Sweden,Technological', (30200.0, '30200'))
#
# ('Austria,Technological', (120000.0, '120000'))
#
# ('Azores Islands,Meteorological', (66000.0, '66000'))
#
# ('Malaysia,Meteorological', (26500.0, 52000.0))
#
# ('Puerto Rico,Technological', (9250.0, 12100.0))
#
# ('Madagascar,Biological', (3500.0, '3500'))
#
# ('Guyana,Climatological', (21850.0, 29000.0))
#
# ('Armenia,Hydrological', (4060.0, 8000.0))
#
# ('Israel,Hydrological', (40000.0, '40000'))
#
# ('Slovakia,Hydrological', (36042.857142857145, 113300.0))
#
# ('Azores Islands,Hydrological', (16300.0, '16300'))
#
# ('Portugal,Meteorological', (136833.33333333334, 270000.0))
#
# ('Peru,Meteorological', (53000.0, 94000.0))
#
# ('Egypt,Technological', (12500.0, 15000.0))
#
# ('Cameroon,Biological', (1700.0, '1700'))
#
# ('Cuba,Climatological', (91569.5, 180000.0))
#
# ('Congo (the),Hydrological', (59.0, '59'))
#
# ('Kyrgyzstan,Technological', (8400.0, '8400'))
#
# ('Mauritius,Climatological', (175000.0, '175000'))
#
# ('Uruguay,Climatological', (375000.0, 500000.0))
#
# ('Iran (Islamic Republic of),Climatological', (3300000.0, '3300000'))
#
# ('Latvia,Meteorological', (162750.0, 325000.0))
#
# ('Tajikistan,Meteorological', (280144.6666666667, 840000.0))
#
# ('Tajikistan,Climatological', (57000.0, '57000'))
#
# ('Uzbekistan,Climatological', (50000.0, '50000'))
#
# ('Azerbaijan,Climatological', (100000.0, '100000'))
#
# ('Georgia,Climatological', (200000.0, '200000'))
#
# ('Romania,Climatological', (500000.0, '500000'))
#
# ('Croatia,Climatological', (122583.33333333333, 330000.0))
#
# ('Zimbabwe,Hydrological', (74125.0, 200000.0))
#
# ('Angola,Hydrological', (6000.0, 10000.0))
#
# ('Morocco,Meteorological', (75214.75, 300000.0))
#
# ('Bulgaria,Meteorological', (272525.0, 545000.0))
#
# ('Croatia,Meteorological', (200500.0, 240000.0))
#
# ('Moldova (the Republic of),Meteorological', (31600.0, '31600'))
#
# ('Chad,Hydrological', (3666.6666666666665, 10000.0))
#
# ('Samoa,Hydrological', (1500.0, '1500'))
#
# ('Cayman Islands (the),Meteorological', (699316.0, 3435080.0))
#
# ('Georgia,Geophysical', (350000.0, '350000'))
#
# ('Dominican Republic (the),Hydrological', (16287.5, 52403.0))
#
# ('Bulgaria,Hydrological', (71266.66666666667, 457000.0))
#
# ('Canary Is,Hydrological', (79923.0, '79923'))
#
# ('American Samoa,Hydrological', (50000.0, '50000'))
#
# ('Madagascar,Hydrological', (150000.0, '150000'))
#
# ('Slovakia,Meteorological', (266650.0, 383300.0))
#
# ('Seychelles,Geophysical', (30000.0, '30000'))
#
# ('Somalia,Geophysical', (100000.0, '100000'))
#
# ('Myanmar,Geophysical', (128692.5, 500000.0))
#
# ('Thailand,Geophysical', (531000.0, 1000000.0))
#
# ('Bangladesh,Geophysical', (500000.0, '500000'))
#
# ('Maldives,Geophysical', (470100.0, '470100'))
#
# ('Sri Lanka,Geophysical', (1316500.0, '1316500'))
#
# ('Algeria,Technological', (800000.0, '800000'))
#
# ("Korea (the Democratic People's Republic of),Technological", (408000.0, '408000'))
#
# ('Somalia,Hydrological', (26673.333333333332, 80000.0))
#
# ('Slovenia,Hydrological', (135000.0, 265000.0))
#
# ('Estonia,Meteorological', (130000.0, '130000'))
#
# ('Namibia,Hydrological', (6830.0, 12000.0))
#
# ('Moldova (the Republic of),Climatological', (406000.0, '406000'))
#
# ('Rwanda,Hydrological', (10001.8, 28000.0))
#
# ('Zimbabwe,Meteorological', (95100.0, 189000.0))
#
# ('Ecuador,Climatological', (1700.0, '1700'))
#
# ('Honduras,Geophysical', (100000.0, '100000'))
#
# ('Croatia,Hydrological', (40000.0, '80000'))
#
# ('Cameroon,Hydrological', (1000.0, '2000'))
#
# ('Nigeria,Meteorological', (1000.0, '1000'))
#
# ('Paraguay,Meteorological', (13500.0, 25000.0))
#
# ('Indonesia,Meteorological', (500.0, '1000'))
#
# ('Russian Federation (the),Extra-terrestrial', (33000.0, '33000'))
#
# ('Solomon Islands,Geophysical', (2000.0, '2000'))
#
# ('Mauritius,Hydrological', (2000.0, '2000'))
#
# ('Mauritania,Hydrological', (2000.0, '2000'))
#
# ('Solomon Islands,Hydrological', (13000.0, 24000.0))
#
# ('Somalia,Meteorological', (2000.0, '2000'))
#
# ('Burundi,Hydrological', (7500.0, 13000.0))
#
# ('Congo (the Democratic Republic of the),Hydrological', (15000.0, '15000'))
#
# ('Serbia,Hydrological', (429652.4, 2048262.0))
#
# ('Yemen,Meteorological', (100000.0, '200000'))
#
# ('United Republic of Tanzania,Geophysical', (458000.0, '458000'))
#
# ('Saudi Arabia,Meteorological', (50000.0, '50000'))
#
# ('French Polynesia,Hydrological', (2000.0, '2000'))
#
# ('Sierra Leone,Hydrological', (30000.0, '30000'))
#
# ('Saint Martin (French Part),Meteorological', (4100000.0, '4100000'))
#
# ('Sint Maarten (Dutch part),Meteorological', (2500000.0, '2500000'))
#
# ('Qatar,Hydrological', (10000.0, '10000'))
#
# ('United States of America (the),Meteorological', (1643781.8846153845, 157530000.0))
#
# ('United States of America (the),Geophysical', (1051748.0487804879, 30002100.0))
#
# ('Jamaica,Geophysical', (30000.0, '30000'))
#
# ('Canada,Meteorological', (299650.0, 2000000.0))
#
# ('Japan,Meteorological', (755851.3761467889, 17000000.0))
#
# ('Japan,Geophysical', (8356443.478260869, 210000000.0))
#
# ('Canada,Technological', (118750.0, 235000.0))
#
# ('United States of America (the),Climatological', (1219588.3720930233, 20000000.0))
#
# ('Germany Fed Rep,Hydrological', (91200.0, 330000.0))
#
# ('Puerto Rico,Meteorological', (5490769.230769231, 68000000.0))
#
# ('Dominican Republic (the),Meteorological', (137662.38095238095, 1981500.0))
#
# ('Nicaragua,Geophysical', (127531.71428571429, 845000.0))
#
# ('China,Hydrological', (948368.1, 31059000.0))
#
# ('Belize,Meteorological', (57009.72727272727, 277460.0))
#
# ('Trinidad and Tobago,Meteorological', (7811.4, 30000.0))
#
# ('Guatemala,Hydrological', (76157.0, 500000.0))
#
# ('Canada,Hydrological', (329737.037037037, 5700000.0))
#
# ('Italy,Hydrological', (638828.8095238095, 9300000.0))
#
# ('Switzerland,Hydrological', (507937.5, 2100000.0))
#
# ('Haiti,Geophysical', (4010000.0, 8000000.0))
#
# ('Algeria,Geophysical', (1141214.3333333333, 5200000.0))
#
# ('Iraq,Hydrological', (14825.0, 50000.0))
#
# ('Afghanistan,Geophysical', (5406.0, 25000.0))
#
# ('Colombia,Technological', (23666.666666666668, 40000.0))
#
# ('New Caledonia,Meteorological', (7316.666666666667, 40000.0))
#
# ('Niue,Meteorological', (13847.0, 40000.0))
#
# ('Morocco,Geophysical', (260000.0, 400000.0))
#
# ('Tonga,Meteorological', (12466.666666666666, 51300.0))
#
# ('Philippines (the),Technological', (2184.9444444444443, 49505.0))
#
# ('Iran (Islamic Republic of),Geophysical', (242127.46153846153, 8232300.0))
#
# ('Peru,Geophysical', (100367.64705882352, 600000.0))
#
# ('Thailand,Meteorological', (50644.444444444445, 452000.0))
#
# ('Dominica,Meteorological', (247006.66666666666, 1456000.0))
#
# ('Haiti,Meteorological', (172995.05263157896, 2000000.0))
#
# ('Martinique,Meteorological', (86626.25, 300000.0))
#
# ('Saint Lucia,Meteorological', (17405.625, 87990.0))
#
# ('Tunisia,Hydrological', (52977.77777777778, 242800.0))
#
# ('India,Hydrological', (281282.9688888889, 16465000.0))
#
# ('Pakistan,Hydrological', (680618.6451612903, 9500000.0))
#
# ('Yugoslavia,Hydrological', (391900.0, 766100.0))
#
# ('Korea (the Republic of),Meteorological', (285014.73913043475, 4500000.0))
#
# ('Panama,Meteorological', (17587.5, 60000.0))
#
# ('Turkey,Meteorological', (201066.66666666666, 600000.0))
#
# ('Sri Lanka,Meteorological', (135075.0, 346000.0))
#
# ('Panama,Technological', (234.66666666666666, 500.0))
#
# ('China,Climatological', (1418256.8, 13755200.0))
#
# ('India,Climatological', (727013.5555555555, 3000000.0))
#
# ('Chile,Hydrological', (109695.23809523809, 1500000.0))
#
# ('Bolivia (Plurinational State of),Hydrological', (87004.53846153847, 590000.0))
#
# ('Myanmar,Meteorological', (408398.8, 4000000.0))
#
# ('Uganda,Geophysical', (35750.0, 70000.0))
#
# ('Congo (the Democratic Republic of the),Geophysical', (5400.0, 9000.0))
#
# ('Sri Lanka,Hydrological', (73530.4, 1200000.0))
#
# ('Thailand,Hydrological', (709754.6666666666, 40000000.0))
#
# ('Togo,Meteorological', (200.0, '200'))
#
# ('Guadeloupe,Meteorological', (99285.71428571429, 300000.0))
#
# ('Samoa,Meteorological', (94134.0, 278000.0))
#
# ('Ecuador,Technological', (25067.0, 50000.0))
#
# ('Peru,Technological', (9857.142857142857, 55000.0))
#
# ('Korea (the Republic of),Technological', (23177.7, 52600.0))
#
# ('Saudi Arabia,Technological', (220.0, '220'))
#
# ('Australia,Climatological', (416032.2702702703, 6000000.0))
#
# ('India,Geophysical', (378407.14285714284, 2623000.0))
#
# ('Uruguay,Hydrological', (18400.0, 45000.0))
#
# ('Venezuela (Bolivarian Republic of),Hydrological', (291493.8333333333, 3160000.0))
#
# ('Mauritius,Meteorological', (69597.0, 200000.0))
#
# ('Nicaragua,Technological', (3750.0, 7000.0))
#
# ('Malaysia,Technological', (7154.333333333333, 18000.0))
#
# ('Belgium,Technological', (40000.0, 100000.0))
#
# ('Botswana,Climatological', (15666.666666666666, 44000.0))
#
# ('Lesotho,Climatological', (1000.0, '1000'))
#
# ('Costa Rica,Geophysical', (33700.0, 200000.0))
#
# ('Kenya,Hydrological', (36313.42857142857, 350000.0))
#
# ('Colombia,Meteorological', (13262.5, 50000.0))
#
# ('Madagascar,Meteorological', (52885.39024390244, 350000.0))
#
# ('Thailand,Technological', (19663.4, 83600.0))
#
# ('Nicaragua,Biological', (7.0, '7'))
#
# ('Ethiopia,Climatological', (373150.0, 1400000.0))
#
# ('Chad,Climatological', (83000.0, '83000'))
#
# ('Senegal,Climatological', (187400.0, 300000.0))
#
# ('Peru,Climatological', (98666.66666666667, 250000.0))
#
# ('Afghanistan,Climatological', (47416.666666666664, 142000.0))
#
# ('Yemen Arab Rep,Climatological', (10000.0, '10000'))
#
# ('Suriname,Hydrological', (50.0, '50'))
#
# ('Colombia,Hydrological', (127370.79310344828, 2320000.0))
#
# ('Cyprus,Meteorological', (5050.0, 10000.0))
#
# ('El Salvador,Meteorological', (189378.88888888888, 939000.0))
#
# ('Honduras,Meteorological', (311545.26666666666, 3793600.0))
#
# ('Papua New Guinea,Geophysical', (20208.333333333332, 110000.0))
#
# ('Hungary,Hydrological', (96640.0, 440000.0))
#
# ('Romania,Hydrological', (156418.1739130435, 1313000.0))
#
# ('Italy,Meteorological', (544789.5263157894, 4400000.0))
#
# ('Australia,Meteorological', (245150.56842105262, 2720000.0))
#
# ('Cameroon,Climatological', (1500.0, '1500'))
#
# ('Morocco,Climatological', (450050.0, 900000.0))
#
# ('Togo,Climatological', (500.0, '500'))
#
# ('Chile,Meteorological', (205860.0, 1000000.0))
#
# ('Niger (the),Hydrological', (38862.71428571428, 184115.0))
#
# ('Grenada,Hydrological', (4700.0, '4700'))
#
# ('Sierra Leone,Meteorological', (3600.0, '3600'))
#
# ('Taiwan (Province of China),Hydrological', (37678.75, 116130.0))
#
# ('Greece,Hydrological', (143039.88888888888, 600000.0))
#
# ('Gambia (the),Technological', (4000.0, '4000'))
#
# ('Zambia,Hydrological', (10450.0, 20700.0))
#
# ('Afghanistan,Hydrological', (30923.076923076922, 260000.0))
#
# ('New Zealand,Hydrological', (48868.58823529412, 245000.0))
#
# ('India,Technological', (57453.846153846156, 410000.0))
#
# ('Barbados,Meteorological', (26675.0, 100000.0))
#
# ('Central African Republic,Meteorological', (125.0, '125'))
#
# ('Denmark,Meteorological', (634991.2857142857, 2604939.0))
#
# ('Jamaica,Technological', (14000.0, '14000'))
#
# ('Zimbabwe,Climatological', (183666.66666666666, 500000.0))
#
# ('Yemen Arab Rep,Geophysical', (2000000.0, '2000000'))
#
# ('El Salvador,Hydrological', (427166.6666666667, 1000000.0))
#
# ('Poland,Hydrological', (1322166.6666666667, 3500000.0))
#
# ('Cabo Verde,Meteorological', (2050.0, 3000.0))
#
# ('Samoa,Climatological', (31650.0, '31650'))
#
# ('Cuba,Hydrological', (50647.5, 140000.0))
#
# ('France,Hydrological', (529210.9090909091, 2400000.0))
#
# ('Papua New Guinea,Hydrological', (16925.6, 43228.0))
#
# ('Poland,Meteorological', (49405.0, 275000.0))
#
# ('Comoros (the),Meteorological', (10701.0, 23000.0))
#
# ('French Polynesia,Meteorological', (16000.0, 37000.0))
#
# ('South Africa,Meteorological', (97645.78571428571, 603000.0))
#
# ('Brazil,Technological', (13333.333333333334, 30000.0))
#
# ('Saudi Arabia,Hydrological', (413000.0, 900000.0))
#
# ('Soviet Union,Hydrological', (381890.0, 2000000.0))
#
# ('Mozambique,Technological', (3700.0, '3700'))
#
# ('Switzerland,Technological', (48550.0, 95600.0))
#
# ('Jamaica,Hydrological', (28073.333333333332, 76000.0))
#
# ('Nepal,Meteorological', (930.75, 3600.0))
#
# ('Greece,Technological', (15000.0, '15000'))
#
# ('Saint Kitts and Nevis,Hydrological', (500.0, '500'))
#
# ('Saint Vincent and the Grenadines,Hydrological', (39833.333333333336, 108000.0))
#
# ('Lebanon,Hydrological', (10000.0, '10000'))
#
# ('Argentina,Meteorological', (13275.0, 50000.0))
#
# ('Czechoslovakia,Meteorological', (15000.0, '15000'))
#
# ('Tokelau,Meteorological', (1450.0, 2400.0))
#
# ('Micronesia (Federated States of),Meteorological', (4375.0, 11000.0))
#
# ('China,Technological', (5532.847826086957, 199000.0))
#
# ('Chad,Meteorological', (157.0, '157'))
#
# ('Guyana,Technological', (7700.0, 15000.0))
#
# ('France,Climatological', (540000.0, 1600000.0))
#
# ('Mexico,Climatological', (283533.3333333333, 1200000.0))
#
# ('American Samoa,Meteorological', (77500.0, 150000.0))
#
# ('Philippines (the),Climatological', (49617.333333333336, 84399.0))
#
# ('Greece,Climatological', (856250.0, 1750000.0))
#
# ('Italy,Climatological', (998333.3333333334, 2300000.0))
#
# ('Belize,Hydrological', (4132.333333333333, 9697.0))
#
# ('Liberia,Meteorological', (47000.0, '47000'))
#
# ('Ireland,Meteorological', (35005.555555555555, 110000.0))
#
# ('Norway,Meteorological', (65750.0, 130000.0))
#
# ('Belgium,Meteorological', (131784.7142857143, 980000.0))
#
# ('Germany,Meteorological', (791020.9459459459, 5500000.0))
#
# ('Luxembourg,Meteorological', (51375.0, 370000.0))
#
# ('Netherlands (the),Technological', (64814.28571428572, 256000.0))
#
# ('Namibia,Climatological', (43750.0, 64000.0))
#
# ('Cambodia,Hydrological', (129190.90909090909, 521000.0))
#
# ('Austria,Hydrological', (386314.1666666667, 2400000.0))
#
# ("Lao People's Democratic Republic (the),Meteorological", (105158.5, 302151.0))
#
# ('Maldives,Meteorological', (30000.0, '30000'))
#
# ('Soviet Union,Meteorological', (24000.0, '24000'))
#
# ('Iran (Islamic Republic of),Technological', (150000.0, '150000'))
#
# ('Denmark,Climatological', (751700.0, '751700'))
#
# ('Egypt,Geophysical', (1200000.0, '1200000'))
#
# ('Kyrgyzstan,Geophysical', (43750.0, 161000.0))
#
# ('Tajikistan,Hydrological', (51732.35294117647, 300000.0))
#
# ('Israel,Meteorological', (276375.0, 550000.0))
#
# ('Lebanon,Meteorological', (155000.0, '155000'))
#
# ('Singapore,Technological', (6137.0, '6137'))
#
# ('Thailand,Climatological', (745100.0, 3300000.0))
#
# ('Guam,Geophysical', (120000.0, '120000'))
#
# ('Kazakhstan,Hydrological', (40367.142857142855, 130000.0))
#
# ('Turkmenistan,Hydrological', (99870.0, '99870'))
#
# ('Belarus,Hydrological', (52190.0, 100000.0))
#
# ('Ukraine,Hydrological', (131901.4, 1000000.0))
#
# ('Belgium,Hydrological', (66286.5, 238146.0))
#
# ('Luxembourg,Hydrological', (10000.0, '10000'))
#
# ('Venezuela (Bolivarian Republic of),Meteorological', (4500.0, '4500'))
#
# ("Korea (the Democratic People's Republic of),Meteorological", (1223030.0, 6000000.0))
#
# ('Indonesia,Technological', (10280.0, 35000.0))
#
# ('United Arab Emirates (the),Technological', (7000.0, '7000'))
#
# ('Jordan,Technological', (1000.0, '1000'))
#
# ('El Salvador,Climatological', (59566.666666666664, 170000.0))
#
# ('Guatemala,Climatological', (42167.25, 100000.0))
#
# ('New Zealand,Climatological', (461500.0, 823000.0))
#
# ('Kyrgyzstan,Hydrological', (7126.666666666667, 36000.0))
#
# ('Russian Federation (the),Technological', (665600.0, 1320000.0))
#
# ('Colombia,Biological', (104000.0, '104000'))
#
# ('Russian Federation (the),Geophysical', (78788.57142857143, 420000.0))
#
# ('Macedonia (the former Yugoslav Republic of),Hydrological', (96400.0, 245000.0))
#
# ("Korea (the Democratic People's Republic of),Hydrological", (1762880.0, 15000000.0))
#
# ('Georgia,Hydrological', (8550.857142857143, 29500.0))
#
# ('Norway,Hydrological', (300000.0, '300000'))
#
# ('Kazakhstan,Meteorological', (3000.0, '3000'))
#
# ('Syrian Arab Republic,Technological', (22500.0, 35000.0))
#
# ('Germany,Technological', (77414.28571428571, 314700.0))
#
# ('Israel,Technological', (37000.0, '37000'))
#
# ('Hungary,Technological', (81500.0, 103000.0))
#
# ('France,Technological', (31700.0, 36800.0))
#
# ('Czech Republic (the),Hydrological', (574411.2, 2400000.0))
#
# ('Comoros (the),Technological', (40000.0, '40000'))
#
# ('Nigeria,Technological', (1000.0, '2000'))
#
# ('Spain,Technological', (2556526.75, 9960407.0))
#
# ('Viet Nam,Climatological', (1849780.0, 6750000.0))
#
# ('Malaysia,Climatological', (151000.0, 300000.0))
#
# ('Trinidad and Tobago,Geophysical', (25000.0, '25000'))
#
# ('Armenia,Geophysical', (33333.0, '33333'))
#
# ('Montserrat,Geophysical', (8000.0, '8000'))
#
# ('Seychelles,Hydrological', (1700.0, '1700'))
#
# ('Uganda,Hydrological', (1374.2, 3100.0))
#
# ('Egypt,Meteorological', (31500.0, 100000.0))
#
# ('Cambodia,Meteorological', (10.0, '10'))
#
# ('Belarus,Meteorological', (24433.333333333332, 33000.0))
#
# ('Brunei Darussalam,Climatological', (2000.0, '2000'))
#
# ('Russian Federation (the),Climatological', (694308.0, 1800000.0))
#
# ('Azores Islands,Geophysical', (72000.0, '72000'))
#
# ('Pakistan,Climatological', (247000.0, '247000'))
#
# ('Bhutan,Climatological', (3500.0, '3500'))
#
# ('Taiwan (Province of China),Geophysical', (1990987.5, 14100800.0))
#
# ('Azerbaijan,Geophysical', (7500.0, 10000.0))
#
# ('Spain,Geophysical', (122002.0, 200000.0))
#
# ('Canary Is,Meteorological', (395000.0, 415000.0))
#
# ('Ethiopia,Technological', (2200.0, 2200.0))
#
# ('Australia,Biological', (120000.0, '120000'))
#
# ('Armenia,Climatological', (100000.0, '100000'))
#
# ('Bosnia and Herzegovina,Climatological', (149000.0, 158000.0))
#
# ('Bulgaria,Climatological', (10027.0, 17600.0))
#
# ('Macedonia (the former Yugoslav Republic of),Climatological', (13563.0, '13563'))
#
# ('Swaziland,Hydrological', (50.0, '50'))
#
# ('Afghanistan,Meteorological', (1670.0, 5000.0))
#
# ('Uruguay,Meteorological', (25000.0, '25000'))
#
# ('Czech Republic (the),Meteorological', (55725.0, 150000.0))
#
# ('Oman,Meteorological', (1034400.0, 3900000.0))
#
# ('Slovenia,Meteorological', (157333.33333333334, 292000.0))
#
# ('Slovenia,Geophysical', (10000.0, '10000'))
#
# ('Kenya,Geophysical', (100000.0, '100000'))
#
# ('Malaysia,Geophysical', (250001.0, 500000.0))
#
# ('South Africa,Geophysical', (20000.0, '20000'))
#
# ('Tajikistan,Geophysical', (9500.0, 22000.0))
#
# ('Hungary,Meteorological', (10000.0, '10000'))
#
# ('Paraguay,Climatological', (30000.0, '30000'))
#
# ('United Kingdom of Great Britain and Northern Ireland (the),Geophysical', (60000.0, '60000'))
#
# ('Ukraine,Technological', (867000.0, '867000'))
#
# ('Samoa,Geophysical', (124040.0, '124040'))
#
# ('Burkina Faso,Hydrological', (45294.0, 150000.0))
#
# ('Serbia,Geophysical', (132260.0, '132260'))
#
# ('Bosnia and Herzegovina,Hydrological', (104716.0, 436580.0))
#
# ('Ukraine,Climatological', (1690000.0, '1690000'))
#
# ('Comoros (the),Hydrological', (5000.0, '5000'))
#
# ('Georgia,Meteorological', (91000.0, '91000'))
#
# ('Panama,Climatological', (136000.0, 200000.0))
#
# ('Bahamas (the),Hydrological', (45000.0, '45000'))
#
# ('Armenia,Meteorological', (30911.0, 60000.0))
#
# ('Seychelles,Meteorological', (9300.0, '9300'))
#
# ('Sri Lanka,Climatological', (22500.0, 25000.0))
#
# ('Papua New Guinea,Climatological', (60000.0, '60000'))
#
# ('Marshall Islands (the),Climatological', (4900.0, '4900'))
#
# ('Timor-Leste,Geophysical', (4000.0, '4000'))
#
# ('Korea (the Republic of),Geophysical', (21000.0, '21000'))
#
# ('Macedonia (the former Yugoslav Republic of),Geophysical', (10000.0, '10000'))
#
# ('Romania,Meteorological', (7300.0, '7300'))
#
# ('Macao,Meteorological', (710000.0, '1420000'))
#
# ('Sweden,Climatological', (102000.0, '102000'))
#
#
# real	0m21.097s
# user	0m0.634s
# sys	0m0.102s
